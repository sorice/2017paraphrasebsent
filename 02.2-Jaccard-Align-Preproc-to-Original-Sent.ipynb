# %% [markdown]
# <small><i>This notebook was put together by [Abel Meneses-Abad](http://www.menesesabad.com) for SciPy LA Habana 2017. Source and license info is on [github repository](http://github.com/sorice/simtext_scipyla2017).</i></small>

# %% [markdown]
# # Sentence Alignment Algorithm Phase
#
# The objective of this phase is to get a <font color='#FA0000'>new text structure</font> with normalized sentences and its original related by the offset and length properties. E.g.:
#
# <a id='Aligned_Text_Structure'></a>
# <font color='#FA0000'>**Aligned Text Structure:**</font>
# If you open a the abstract-name file *suspicious-document00XYZ.txt*, then you would get a text with de following structure in every line:
#
# <p><font color='#FA0000'>
#    $(id_K,normalized\ sentence_K,original\_offset_{sentence\,K},original\_offset+length_{sentence\,K})$
#    </font>
#
# *Why we need this?*
# This is useful for example when you are working in a real plagiarism detection or text-reuse detection applications and you need to show to the users the similarity result between the preprocessed fragments or sentences and its original form (pdf, html, etc). Additionally is very safe to work with duplicated or transformed objects very well related to the originals, after have them you can do subsequent transformations to the copy-object and never loss the original length and position of this sentence or fragment.

# %% [markdown]
# # Alignment Algorithm based on Jaccard Distance
#
# The final algorithm needs 4 auxiliar functions:
#
# 1. A character replacement function in the original text in which Jaccard (and others) fails (*Eg: line breaks*) (**normalize**)
# 2. A function to look over the list of sentences of the preproces text (**getSentA**).
# 3. A function to look over the list of segments of the original-text ending with '.'(**getSentB**).
# 4. Jaccard function to validate Smith-Watermna alignment (**Jaccard**).

# %%
#Import cell
import re
import sys

# %% [markdown]
# ## Original Text Normalization Function
#
# To improve the precision of Jaccard algorithm is necessary to convert some punctuation situation.
# The main feature here is that whole regular expressions and functiones used does not change the length of the original text. The [previous](02.1-Normalizing-Text-Corpus.ipynb) normalization process it doesn't.

# %%
from preprocess.normalize import  add_doc_ending_point, abbreviations
from preprocess.normalize import  multipart_words, replace_point_sequence


def normalize(text_orig):
    replacement_patterns = [(r'[:](?=\s*?\n)','##1'),
                            (r'\xc2|\xa0',' '),
                            (r'(\w\s*?):(?=\s+?[A-Z]+?)|(\w\s*?):(?=\s*?"+?[A-Z]+?)','\g<1>##2'),
                            (r'[?!]','##3'),
                            # any alphanumeric char follow by \n then by punct-sign then by Capital new sent
                            (r'(\w+?)(\n)(?=["$%()*+&,-/;:¿¡<=>@[\\]^`{|}~\t\s]*(?=.*[A-Z0-9]))','\g<1>##4'), 
                            # alphanum follow by \n follow by any number of point-sign 
                            #follow by a capital letter, replace by alphanumerig+.
                            (r'(\w+?)(\n)(?=["$%()*+&,-/;:¿¡<=>@[\\]^`{|}~\t\s\n]*(?=[a-zA-Z0-9]))','\g<1>##5'),
                            (r'[:](?=\s*?)(?=["$%()*+&,-/;:¿¡<=>@[\\]^`{|}~\t\s]*[A-Z]+?)','##6'),
                            (r'(\w+?\s*?)\|','\g<1>##7'),
                            (r'\n(?=\s*?[A-Z]+?)','##8'),
                            (r'[.](?=\s*?\n+?[a-z]+?)', '##8'),
                            (r'[.](?=\s+?[a-z]+?)', '_'),
                            (r'##\d','apdbx'),
                            ]
    
    for (pattern, repl) in replacement_patterns:
            (text_orig, count) = re.subn(pattern, repl, text_orig)
    
    text_orig = replace_point_sequence(text_orig)
    text_orig = multipart_words(text_orig)
    text_orig = abbreviations(text_orig)
    text_orig = re.sub(r'apdbx+','.', text_orig)
    text_orig = add_doc_ending_point(text_orig)#append . final si el último caracter no tiene punto, evita un ciclo infinito al final.
    return text_orig

# %% [markdown]
# This minimal normalization function has been created only with the purpouse to delete some troublesome strings without any lenght modification, the normalization demo flow used in preprocess library change the lenght of all texts.

# %%
orig_text = open('data/orig/src/source-document00534.txt').read()
print(len(orig_text))
norm_text = normalize(orig_text)
print(len(norm_text))
# Out:
# 12237
# 12237

# %% [markdown]
# ## Get Sentence A
#
# Get all sentences in preprocessed text.

# %%
def getSentA(text):
    offset = 0
    for i in re.finditer('\.',text):
        sentA = text[offset:i.end()]
        yield sentA, offset, i.end()
        offset = i.end()+1

# %%
#Example of getSentA use
preprocessed_text = open('data/norm/susp/suspicious-document00184.txt').read()
        
for i,(sentA, offset, length) in enumerate(getSentA(preprocessed_text)):
    print (i,sentA, offset, length)
# Out:
# 0 The is a 5 acre 20 000 m located in the of located in . 0 55
# 1 The zoo is operated by the in partnership with the . 56 108
# 2 Queens Zoo zoo New York City borough Queens Flushing Meadows_Corona Park Wildlife Conservation Society New York City Department of Parks and Recreation . 109 262
# 3 The Zoo opened on with the ceremonial ribbon cut by . 263 316
# 4 The zoo is home mostly to animals native to North America . 317 376
# 5 The Queens Zoo is the only one of the five zoos in New York City to exhibit . 377 454
# 6 The zoo was constructed on the site of the and the zoo is aviary is a designed by and used during the 1964 Fair . 455 568
# 7 October 26 1968 Robert Moses 2 Spectacled Bears 1964 New York World is Fair geodesic dome Buckminster Fuller 1  . 569 682

# %% [markdown]
# ## Get Sentence B
#
# <center><strong>Diagrama simplificado getSentB function.</strong></center></br>
# <table border=0 cellspacing=10>
#     <caption align="bottom"> </br><em>Figura 2.3.1: Esquema del Algoritmo Get Sentence B</em>
#     </caption>
# <tr align="center">
#     <th> <img src="imgs/getSentB.jpg" height=800px width=1200px alt="*"
#         align="center"> </th>
#     <th> </th>
#     <td>
#         <p> El algoritmo comienza a buscar en el texto original el caracter '.'  más cercano al offsetB (*$\|\overrightarrow{sB}\|=0 \Longrightarrow sentLength = 0$*).
#         Una vez encontrado denota como punto previo este nuevo punto para una nueva llamada (*$sentLength = \|\overrightarrow{sB}\|+1$*),
#         luego calcula el segmento, y define el punto siguiente como $Offset + \|\overrightarrow{sB}\|$ *(len segmento definido por el . encontrado)*.
#         En la siguiente corrida el algoritmo encontrará el '.' más cercano a partir de **sB**
#         calculando el nuevo punto siguiente(*sB`*). Y así sucesivamente
#         ante cada llamada en la función *getSentB*. Es en la función de alineación donde se establece la condición
#         de parada cuando el score de Smith-Waterman es máximo entre el *$\|\overrightarrow{sB^{n`}}\|$ y *length sentA*.
#         </p>
#     </td>
# </tr>
# </table>

# %%
def getOrigSent(text2, offsetB, nextPoint,sentLength):
    posB = text2[offsetB+sentLength:].find('.')
    sentLength += posB+1
    sentB = text2[offsetB:offsetB+sentLength]
    nextPoint = offsetB + sentLength
    return sentB, nextPoint, sentLength

text_orig = open('data/orig/susp/suspicious-document00184.txt').read()

offsetB = 0;nextPoint = 0;sentLength=0

for i in range(text_orig.count('.')):
    sentB, nextPoint, sentLength = getOrigSent(text_orig,offsetB,nextPoint,sentLength)
    print('i',i,'sentB:',sentB)
    print('offsetB:', offsetB, 'nextPoint:', nextPoint, 'sentLength', sentLength)
    print('***************')
    if i == 2: #This is a cuting point see the explanation below
        offsetB = nextPoint
        nextPoint = 0
        sentLength = 0
# Out:
# i 0 sentB: The is a 5 acre (20,000 m ) located in the of , located in .
# offsetB: 0 nextPoint: 60 sentLength 60
# ***************
# i 1 sentB: The is a 5 acre (20,000 m ) located in the of , located in . The zoo is operated by the in partnership with the .
# offsetB: 0 nextPoint: 113 sentLength 113
# ***************
# i 2 sentB: The is a 5 acre (20,000 m ) located in the of , located in . The zoo is operated by the in partnership with the .Queens Zoo zoo New York City borough Queens Flushing Meadows-Corona Park Wildlife Conservation Society New York City Department of Parks and Recreation
# The Zoo opened on , , with the ceremonial ribbon cut by .
# offsetB: 0 nextPoint: 322 sentLength 322
# ***************
# i 3 sentB:  The zoo is home mostly to animals native to North America.
# offsetB: 322 nextPoint: 381 sentLength 59
# ***************
# i 4 sentB:  The zoo is home mostly to animals native to North America. The Queens Zoo is the only one of the five zoos in New York City to exhibit .
# offsetB: 322 nextPoint: 459 sentLength 137
# ***************
# i 5 sentB:  The zoo is home mostly to animals native to North America. The Queens Zoo is the only one of the five zoos in New York City to exhibit . The zoo was constructed on the site of the , and the zoo's aviary is a , designed by and used during the 1964 Fair.
# offsetB: 322 nextPoint: 575 sentLength 253
# ***************

# %% [markdown]
# **Note:** as you can prove later in the alingment algorithm, when sentA match with sentB the value of the offset parameter is equalized to *nextPoint*. Then the algorithm start to look for the next sentB from the final position (*last* **nextPoint**) of previous sentB. In the above example 322 is at the same time the las nextPoint(& len) of $sentB_1$, and the offset of $sentB_2$, this one start with the string: *The zoo is home mostly...*.

# %% [markdown]
# ## Jaccard Function
#
# Originally Jaccard distance is evaluated as $(A\cup B- B\cap A)/B\cup A)$, which means the fraction between different labels and similar labels inside A & B sets. Here we implement a variation $Jaccard=(B\cap A)/B\cup A)$, which means the fraction between common terms and the total different terms.

# %%
def jaccard(text1,text2):
    sentA1 = re.sub(r'[!"#$%&()\'*+,-/:;<=>?@\\^_`{|}~.\[\]]',' ', text1)
    sentB1 = re.sub(r'[!"#$%&()\'*+,-/:;<=>?@\\^_`{|}~.\[\]]',' ', text2)
    setA = set(sentA1.split())
    setB = set(sentB1.split())
    total_terms = len(sentB1.split())
    return len(setA.intersection(setB))/(total_terms or 0)

# %% [markdown]
# # Alignment Pipeline
#
# * The next code print jaccard score between sentence A & B.
# * Then print the maximal score finded for a chunck B given sentence A.
# * Next the main properties of chunck B (offset & length) are printed.
# * Finally for a visual comparation of result sentence A is printed.
#
# **Nota:** To see more details about how process occurs uncomment the *print* orders.

# %%
import re

def alignSentences(preproc_text, orig_text):
    sentenceList=[]
    offsetB = 0
    
    norm_orig_text = normalize(orig_text)
    
    #if preproc_text.count('.') > norm_orig_text.count('.'):
    #    raise Exception("Preprocess Error: number of preproc periods most be less or equal than normalize original text periods.")
        
    for i, (sentA, offsetA, lengthA) in enumerate(getSentA(preproc_text)):
        maxScore =-1; score = 0
        prevPoint = 0 #len(sentA)-2
        nextPoint = 0
        iqualScore = 0
        prevFrag=''
        jaccard_measure = 0
        prev_jaccard_measure = 1.0
        k = 0.5
        
        #Sí llegamos a la última oración entonces
        if i == preproc_text.count('.')-1: 
            lengMax = len(norm_orig_text)
            tuple = (i, sentA, offsetB, lengMax)
            sentenceList.append(tuple)
            break
        
        #Sí no es la última oración compara hasta encontrar el score max.
        while(score >= maxScore):
            prev_jaccard_measure = jaccard_measure #only for print reasons
            lengMax = nextPoint
            maxScore = score
            
            #Get original Sentence and prepare it to calc distances
            print('-----from',offsetB,'---- to prevPoint', offsetB+prevPoint)
            sentB, nextPoint, prevPoint = getOrigSent(norm_orig_text, offsetB, nextPoint, prevPoint)
            print('-----to nextPoint',nextPoint)
            print('OrigSent:\n',sentB,'\n')
            print('sentA:',sentA,'\n')
            
            #Calc measures Jaccard
            jaccard_measure = jaccard ( sentA , sentB) #Second measure only to lookfor errors
            print ('jaccard_measure:',jaccard_measure)
            
            score = jaccard_measure
            print('i:',i,'score:',score,'maxScore:',maxScore)
            print('frag-sentA:',sentA[-round(len(sentA)*k):],'\nfrag-sentB:',sentB[-round(len(sentA)*k):],'\n')
            
            #Repeated sentence exception src00014
            if prevFrag == sentB[-round(len(sentA)*k):]:
                #print ('=================Repeated sentence')
                break
            
            #keep the previous fragment to know if the next sent is the same as before. 
            #The algh move forward to the next sentence.
            prevFrag = sentB[-round(len(sentA)*k):] 
            
            #Short sentence exceptions
            if len(sentA) < 14:
                maxScore = score
                lengMax = nextPoint
                break
                
            #Infinite loop exception
            if score == maxScore:
                iqualScore += 1
            if iqualScore == 20:
                break
           
        #Raising error because of normalization troubles
        print('maxScore',maxScore)
        if maxScore < 0.5:
            raise ValueError('A normalization error detected.')
        
        tuple = (i, sentA, offsetB, lengMax)
        sentenceList.append(tuple)
        
        if i > -1:
            print ('Final',i,'\njaccard_measure:',prev_jaccard_measure)
            print('Sentence' ,i, 'score max:',maxScore, 'offsetB:', offsetB, 'lengthB:',lengMax-offsetB,'\n')
            print('sent original:',orig_text[offsetB:lengMax],'\n')
            print('sent process:',sentA)
            print('\n***************')
        
        offsetB = lengMax

    return sentenceList
#suspicious-document00017.txt source-document00534.txt
#text_orig = open('data/orig/susp/suspicious-document00017.txt').read()
#preproc_text = open('data/norm/susp/suspicious-document00017.txt').read()

text_orig = open('data/orig/src/source-document00534.txt').read()
preproc_text = open('data/norm/src/source-document00534.txt').read()

sentenceList = alignSentences(preproc_text,text_orig)
# Out:
# -----from 0 ---- to prevPoint 0
# -----to nextPoint 19
# OrigSent:
#  0 [] edit Vehicles.
#
# sentA: 0 edit Vehicles .
#
# jaccard_measure: 1.0
# i: 0 score: 1.0 maxScore: 0
# frag-sentA: hicles .
# frag-sentB: ehicles.
#
# -----from 0 ---- to prevPoint 19
# -----to nextPoint 48
# OrigSent:
#  0 [] edit Vehicles.The Maine State polices uses.
#
# sentA: 0 edit Vehicles .
#
# jaccard_measure: 0.375
# i: 0 score: 0.375 maxScore: 1.0
# frag-sentA: hicles .
# frag-sentB: es uses.
#
# maxScore 1.0
# Final 0
# jaccard_measure: 1.0
# Sentence 0 score max: 1.0 offsetB: 0 lengthB: 19
#
# sent original: 0 [] edit Vehicles
#
#
# sent process: 0 edit Vehicles .
#
# ***************
# -----from 19 ---- to prevPoint 19
# -----to nextPoint 48
# OrigSent:
#  The Maine State polices uses.
#
# sentA: The Maine State polices uses .
#
# jaccard_measure: 1.0
# i: 1 score: 1.0 maxScore: 0
# frag-sentA:  polices uses .
# frag-sentB: e polices uses.
#
# -----from 19 ---- to prevPoint 48
# -----to nextPoint 94
# OrigSent:
#  The Maine State polices uses.Ford and in both marked and unmarked versions.
#
# sentA: The Maine State polices uses .
#
# jaccard_measure: 0.38461538461538464
# i: 1 score: 0.38461538461538464 maxScore: 1.0
# frag-sentA:  polices uses .
# frag-sentB: arked versions.
#
# maxScore 1.0
# Final 1
# jaccard_measure: 1.0
# Sentence 1 score max: 1.0 offsetB: 19 lengthB: 29
#
# sent original: The Maine State polices uses
#
#
# sent process: The Maine State polices uses .
#
# ***************
# -----from 48 ---- to prevPoint 48
# -----to nextPoint 94
# OrigSent:
#  Ford and in both marked and unmarked versions.
#
# sentA: Ford and in both marked and unmarked versions .
#
# jaccard_measure: 0.875
# i: 2 score: 0.875 maxScore: 0
# frag-sentA:  and unmarked versions .
# frag-sentB: d and unmarked versions.
#
# -----from 48 ---- to prevPoint 94
# -----to nextPoint 141
# OrigSent:
#  Ford and in both marked and unmarked versions. 0 921 The marked versions are a dark sky blue.
#
# sentA: Ford and in both marked and unmarked versions .
#
# jaccard_measure: 0.3888888888888889
# i: 2 score: 0.3888888888888889 maxScore: 0.875
# frag-sentA:  and unmarked versions .
# frag-sentB: ons are a dark sky blue.
#
# maxScore 0.875
# Final 2
# jaccard_measure: 0.875
# Sentence 2 score max: 0.875 offsetB: 48 lengthB: 46
#
# sent original: Ford and in both marked and unmarked versions.
#
# sent process: Ford and in both marked and unmarked versions .
#
# ***************
# -----from 94 ---- to prevPoint 94
# -----to nextPoint 141
# OrigSent:
#   0 921 The marked versions are a dark sky blue.
#
# sentA: 0 921 The marked versions are a dark sky blue .
#
# jaccard_measure: 1.0
# i: 3 score: 1.0 maxScore: 0
# frag-sentA: ns are a dark sky blue .
# frag-sentB: ons are a dark sky blue.
#
# -----from 94 ---- to prevPoint 141
# -----to nextPoint 188
# OrigSent:
#   0 921 The marked versions are a dark sky blue. 92 1332 Unmarked cars are a variety of colors.
#
# sentA: 0 921 The marked versions are a dark sky blue .
#
# jaccard_measure: 0.5263157894736842
# i: 3 score: 0.5263157894736842 maxScore: 1.0
# frag-sentA: ns are a dark sky blue .
# frag-sentB: are a variety of colors.
#
# maxScore 1.0
# Final 3
# jaccard_measure: 1.0
# Sentence 3 score max: 1.0 offsetB: 94 lengthB: 47
#
# sent original:  0 921 The marked versions are a dark sky blue.
#
# sent process: 0 921 The marked versions are a dark sky blue .
#
# ***************
# -----from 141 ---- to prevPoint 141
# -----to nextPoint 188
# OrigSent:
#   92 1332 Unmarked cars are a variety of colors.
#
# sentA: 92 1332 Unmarked cars are a variety of colors .
#
# jaccard_measure: 1.0
# i: 4 score: 1.0 maxScore: 0
# frag-sentA: re a variety of colors .
# frag-sentB: are a variety of colors.
#
# -----from 141 ---- to prevPoint 188
# -----to nextPoint 267
# OrigSent:
#   92 1332 Unmarked cars are a variety of colors. 133 1723 Police Interceptor
# , unmarked, in the same blue color, Ford Mustangs.
#
# sentA: 92 1332 Unmarked cars are a variety of colors .
#
# jaccard_measure: 0.42857142857142855
# i: 4 score: 0.42857142857142855 maxScore: 1.0
# frag-sentA: re a variety of colors .
# frag-sentB: ue color, Ford Mustangs.
#
# maxScore 1.0
# Final 4
# jaccard_measure: 1.0
# Sentence 4 score max: 1.0 offsetB: 141 lengthB: 47
#
# sent original:  92 1332 Unmarked cars are a variety of colors.
#
# sent process: 92 1332 Unmarked cars are a variety of colors .
#
# ***************
# -----from 188 ---- to prevPoint 188
# -----to nextPoint 267
# OrigSent:
#   133 1723 Police Interceptor
# , unmarked, in the same blue color, Ford Mustangs.
#
# sentA: 133 1723 Police Interceptor unmarked in the same blue color Ford Mustangs .
#
# jaccard_measure: 1.0
# i: 5 score: 1.0 maxScore: 0
# frag-sentA: in the same blue color Ford Mustangs .
# frag-sentB: in the same blue color, Ford Mustangs.
#
# -----from 188 ---- to prevPoint 267
# -----to nextPoint 331
# OrigSent:
#   133 1723 Police Interceptor
# , unmarked, in the same blue color, Ford Mustangs.Chevy Impalas, unmarked, for traffic patrol and detective cars,.
#
# sentA: 133 1723 Police Interceptor unmarked in the same blue color Ford Mustangs .
#
# jaccard_measure: 0.5714285714285714
# i: 5 score: 0.5714285714285714 maxScore: 1.0
# frag-sentA: in the same blue color Ford Mustangs .
# frag-sentB: or traffic patrol and detective cars,.
#
# maxScore 1.0
# Final 5
# jaccard_measure: 1.0
# Sentence 5 score max: 1.0 offsetB: 188 lengthB: 79
#
# sent original:  133 1723 Police Interceptor
# , unmarked, in the same blue color, Ford Mustangs
#
#
# sent process: 133 1723 Police Interceptor unmarked in the same blue color Ford Mustangs .
#
# ***************
# -----from 267 ---- to prevPoint 267
# -----to nextPoint 331
# OrigSent:
#  Chevy Impalas, unmarked, for traffic patrol and detective cars,.
#
# sentA: Chevy Impalas unmarked for traffic patrol and detective cars .
#
# jaccard_measure: 1.0
# i: 6 score: 1.0 maxScore: 0
# frag-sentA: fic patrol and detective cars .
# frag-sentB: fic patrol and detective cars,.
#
# -----from 267 ---- to prevPoint 331
# -----to nextPoint 412
# OrigSent:
#  Chevy Impalas, unmarked, for traffic patrol and detective cars,.Chevy Suburbans, usually marked, usually used for commercial vehicle enforcement.
#
# sentA: Chevy Impalas unmarked for traffic patrol and detective cars .
#
# jaccard_measure: 0.47368421052631576
# i: 6 score: 0.47368421052631576 maxScore: 1.0
# frag-sentA: fic patrol and detective cars .
# frag-sentB: commercial vehicle enforcement.
#
# maxScore 1.0
# Final 6
# jaccard_measure: 1.0
# Sentence 6 score max: 1.0 offsetB: 267 lengthB: 64
#
# sent original: Chevy Impalas, unmarked, for traffic patrol and detective cars,
#
#
# sent process: Chevy Impalas unmarked for traffic patrol and detective cars .
#
# ***************
# -----from 331 ---- to prevPoint 331
# -----to nextPoint 412
# OrigSent:
#  Chevy Suburbans, usually marked, usually used for commercial vehicle enforcement.
#
# sentA: Chevy Suburbans usually marked usually used for commercial vehicle enforcement .
#
# jaccard_measure: 0.9
# i: 7 score: 0.9 maxScore: 0
# frag-sentA: sed for commercial vehicle enforcement .
# frag-sentB: used for commercial vehicle enforcement.
#
# -----from 331 ---- to prevPoint 412
# -----to nextPoint 528
# OrigSent:
#  Chevy Suburbans, usually marked, usually used for commercial vehicle enforcement.Various trucks such as the , , and Ford Expedition, usually marked, usually used for commercial vehicle enforcement.
#
# sentA: Chevy Suburbans usually marked usually used for commercial vehicle enforcement .
#
# jaccard_measure: 0.34615384615384615
# i: 7 score: 0.34615384615384615 maxScore: 0.9
# frag-sentA: sed for commercial vehicle enforcement .
# frag-sentB: used for commercial vehicle enforcement.
#
# maxScore 0.9
# Final 7
# jaccard_measure: 0.9
# Sentence 7 score max: 0.9 offsetB: 331 lengthB: 81
#
# sent original: Chevy Suburbans, usually marked, usually used for commercial vehicle enforcement
#
#
# sent process: Chevy Suburbans usually marked usually used for commercial vehicle enforcement .
#
# ***************
# -----from 412 ---- to prevPoint 412
# -----to nextPoint 528
# OrigSent:
#  Various trucks such as the , , and Ford Expedition, usually marked, usually used for commercial vehicle enforcement.
#
# sentA: Various trucks such as the and Ford Expedition usually marked usually used for commercial vehicle enforcement .
#
# jaccard_measure: 0.9375
# i: 8 score: 0.9375 maxScore: 0
# frag-sentA: marked usually used for commercial vehicle enforcement .
# frag-sentB: marked, usually used for commercial vehicle enforcement.
#
# -----from 412 ---- to prevPoint 528
# -----to nextPoint 558
# OrigSent:
#  Various trucks such as the , , and Ford Expedition, usually marked, usually used for commercial vehicle enforcement. 172 5034 Ford F150 Dodge Ram.
#
# sentA: Various trucks such as the and Ford Expedition usually marked usually used for commercial vehicle enforcement .
#
# jaccard_measure: 0.6818181818181818
# i: 8 score: 0.6818181818181818 maxScore: 0.9375
# frag-sentA: marked usually used for commercial vehicle enforcement .
# frag-sentB: rcial vehicle enforcement. 172 5034 Ford F150 Dodge Ram.
#
# maxScore 0.9375
# Final 8
# jaccard_measure: 0.9375
# Sentence 8 score max: 0.9375 offsetB: 412 lengthB: 116
#
# sent original: Various trucks such as the , , and Ford Expedition, usually marked, usually used for commercial vehicle enforcement.
#
# sent process: Various trucks such as the and Ford Expedition usually marked usually used for commercial vehicle enforcement .
#
# ***************
# -----from 528 ---- to prevPoint 528
# -----to nextPoint 558
# OrigSent:
#   172 5034 Ford F150 Dodge Ram.
#
# sentA: 172 5034 Ford F150 Dodge Ram .
#
# jaccard_measure: 1.0
# i: 9 score: 1.0 maxScore: 0
# frag-sentA: 150 Dodge Ram .
# frag-sentB: F150 Dodge Ram.
#
# -----from 528 ---- to prevPoint 558
# -----to nextPoint 649
# OrigSent:
#   172 5034 Ford F150 Dodge Ram.MSP's new cars are have interior_mounted emergency lighting, with no lightbars on the roof.
#
# sentA: 172 5034 Ford F150 Dodge Ram .
#
# jaccard_measure: 0.2727272727272727
# i: 9 score: 0.2727272727272727 maxScore: 1.0
# frag-sentA: 150 Dodge Ram .
# frag-sentB: rs on the roof.
#
# maxScore 1.0
# Final 9
# jaccard_measure: 1.0
# Sentence 9 score max: 1.0 offsetB: 528 lengthB: 30
#
# sent original:  172 5034 Ford F150 Dodge Ram
#
#
# sent process: 172 5034 Ford F150 Dodge Ram .
#
# ***************
# -----from 558 ---- to prevPoint 558
# -----to nextPoint 649
# OrigSent:
#  MSP's new cars are have interior_mounted emergency lighting, with no lightbars on the roof.
#
# sentA: MSP is new cars are have interior_mounted emergency lighting with no lightbars on the roof .
#
# jaccard_measure: 0.9375
# i: 10 score: 0.9375 maxScore: 0
# frag-sentA: gency lighting with no lightbars on the roof .
# frag-sentB: gency lighting, with no lightbars on the roof.
#
# -----from 558 ---- to prevPoint 649
# -----to nextPoint 800
# OrigSent:
#  MSP's new cars are have interior_mounted emergency lighting, with no lightbars on the roof. 503 6155 The marked cars usually have "ghost graphics," lettering in a blue slightly darker than the color of the car but not easily seen at a glance.
#
# sentA: MSP is new cars are have interior_mounted emergency lighting with no lightbars on the roof .
#
# jaccard_measure: 0.3409090909090909
# i: 10 score: 0.3409090909090909 maxScore: 0.9375
# frag-sentA: gency lighting with no lightbars on the roof .
# frag-sentB: or of the car but not easily seen at a glance.
#
# maxScore 0.9375
# Final 10
# jaccard_measure: 0.9375
# Sentence 10 score max: 0.9375 offsetB: 558 lengthB: 91
#
# sent original: MSP's new cars are have interior-mounted emergency lighting, with no lightbars on the roof.
#
# sent process: MSP is new cars are have interior_mounted emergency lighting with no lightbars on the roof .
#
# ***************
# -----from 649 ---- to prevPoint 649
# -----to nextPoint 800
# OrigSent:
#   503 6155 The marked cars usually have "ghost graphics," lettering in a blue slightly darker than the color of the car but not easily seen at a glance.
#
# sentA: 503 6155 The marked cars usually have ghost graphics lettering in a blue slightly darker than the color of the car but not easily seen at a glance .
#
# jaccard_measure: 0.9285714285714286
# i: 11 score: 0.9285714285714286 maxScore: 0
# frag-sentA: lightly darker than the color of the car but not easily seen at a glance .
# frag-sentB: slightly darker than the color of the car but not easily seen at a glance.
#
# -----from 649 ---- to prevPoint 800
# -----to nextPoint 940
# OrigSent:
#   503 6155 The marked cars usually have "ghost graphics," lettering in a blue slightly darker than the color of the car but not easily seen at a glance. 615 7576 Finally, while most marked units have blue license plates, many detective and unmarked units have regular civilian license plates.
#
# sentA: 503 6155 The marked cars usually have ghost graphics lettering in a blue slightly darker than the color of the car but not easily seen at a glance .
#
# jaccard_measure: 0.5306122448979592
# i: 11 score: 0.5306122448979592 maxScore: 0.9285714285714286
# frag-sentA: lightly darker than the color of the car but not easily seen at a glance .
# frag-sentB: s, many detective and unmarked units have regular civilian license plates.
#
# maxScore 0.9285714285714286
# Final 11
# jaccard_measure: 0.9285714285714286
# Sentence 11 score max: 0.9285714285714286 offsetB: 649 lengthB: 151
#
# sent original:  503 6155 The marked cars usually have "ghost graphics," lettering in a blue slightly darker than the color of the car but not easily seen at a glance.
#
# sent process: 503 6155 The marked cars usually have ghost graphics lettering in a blue slightly darker than the color of the car but not easily seen at a glance .
#
# ***************
# -----from 800 ---- to prevPoint 800
# -----to nextPoint 940
# OrigSent:
#   615 7576 Finally, while most marked units have blue license plates, many detective and unmarked units have regular civilian license plates.
#
# sentA: 615 7576 Finally while most marked units have blue license plates many detective and unmarked units have regular civilian license plates .
#
# jaccard_measure: 0.8095238095238095
# i: 12 score: 0.8095238095238095 maxScore: 0
# frag-sentA: y detective and unmarked units have regular civilian license plates .
# frag-sentB: ny detective and unmarked units have regular civilian license plates.
#
# -----from 800 ---- to prevPoint 940
# -----to nextPoint 994
# OrigSent:
#   615 7576 Finally, while most marked units have blue license plates, many detective and unmarked units have regular civilian license plates. 757 8887 [] edit Training and Qualification Programs.
#
# sentA: 615 7576 Finally while most marked units have blue license plates many detective and unmarked units have regular civilian license plates .
#
# jaccard_measure: 0.6071428571428571
# i: 12 score: 0.6071428571428571 maxScore: 0.8095238095238095
# frag-sentA: y detective and unmarked units have regular civilian license plates .
# frag-sentB: license plates. 757 8887 [] edit Training and Qualification Programs.
#
# maxScore 0.8095238095238095
# Final 12
# jaccard_measure: 0.8095238095238095
# Sentence 12 score max: 0.8095238095238095 offsetB: 800 lengthB: 140
#
# sent original:  615 7576 Finally, while most marked units have blue license plates, many detective and unmarked units have regular civilian license plates.
#
# sent process: 615 7576 Finally while most marked units have blue license plates many detective and unmarked units have regular civilian license plates .
#
# ***************
# -----from 940 ---- to prevPoint 940
# -----to nextPoint 994
# OrigSent:
#   757 8887 [] edit Training and Qualification Programs.
#
# sentA: 757 8887 edit Training and Qualification Programs .
#
# jaccard_measure: 1.0
# i: 13 score: 1.0 maxScore: 0
# frag-sentA: d Qualification Programs .
# frag-sentB: nd Qualification Programs.
#
# -----from 940 ---- to prevPoint 994
# -----to nextPoint 1133
# OrigSent:
#   757 8887 [] edit Training and Qualification Programs.Maine State Troopers go through an intense and rigorous 18_week training period at the Maine Criminal Justice Academy in Vassalboro, Maine.
#
# sentA: 757 8887 edit Training and Qualification Programs .
#
# jaccard_measure: 0.2413793103448276
# i: 13 score: 0.2413793103448276 maxScore: 1.0
# frag-sentA: d Qualification Programs .
# frag-sentB: demy in Vassalboro, Maine.
#
# maxScore 1.0
# Final 13
# jaccard_measure: 1.0
# Sentence 13 score max: 1.0 offsetB: 940 lengthB: 54
#
# sent original:  757 8887 [] edit Training and Qualification Programs
#
#
# sent process: 757 8887 edit Training and Qualification Programs .
#
# ***************
# -----from 994 ---- to prevPoint 994
# -----to nextPoint 1133
# OrigSent:
#  Maine State Troopers go through an intense and rigorous 18_week training period at the Maine Criminal Justice Academy in Vassalboro, Maine.
#
# sentA: Maine State Troopers go through an intense and rigorous 18_week training period at the Maine Criminal Justice Academy in Vassalboro Maine .
#
# jaccard_measure: 0.9090909090909091
# i: 14 score: 0.9090909090909091 maxScore: 0
# frag-sentA: ing period at the Maine Criminal Justice Academy in Vassalboro Maine .
# frag-sentB: ing period at the Maine Criminal Justice Academy in Vassalboro, Maine.
#
# -----from 994 ---- to prevPoint 1133
# -----to nextPoint 1228
# OrigSent:
#  Maine State Troopers go through an intense and rigorous 18_week training period at the Maine Criminal Justice Academy in Vassalboro, Maine. 888 10728 The entrance standards to the Academy are some of the toughest in the United States.
#
# sentA: Maine State Troopers go through an intense and rigorous 18_week training period at the Maine Criminal Justice Academy in Vassalboro Maine .
#
# jaccard_measure: 0.5128205128205128
# i: 14 score: 0.5128205128205128 maxScore: 0.9090909090909091
# frag-sentA: ing period at the Maine Criminal Justice Academy in Vassalboro Maine .
# frag-sentB: tandards to the Academy are some of the toughest in the United States.
#
# maxScore 0.9090909090909091
# Final 14
# jaccard_measure: 0.9090909090909091
# Sentence 14 score max: 0.9090909090909091 offsetB: 994 lengthB: 139
#
# sent original: Maine State Troopers go through an intense and rigorous 18-week training period at the Maine Criminal Justice Academy in Vassalboro, Maine.
#
# sent process: Maine State Troopers go through an intense and rigorous 18_week training period at the Maine Criminal Justice Academy in Vassalboro Maine .
#
# ***************
# -----from 1133 ---- to prevPoint 1133
# -----to nextPoint 1228
# OrigSent:
#   888 10728 The entrance standards to the Academy are some of the toughest in the United States.
#
# sentA: 888 10728 The entrance standards to the Academy are some of the toughest in the United States .
#
# jaccard_measure: 0.8823529411764706
# i: 15 score: 0.8823529411764706 maxScore: 0
# frag-sentA:  are some of the toughest in the United States .
# frag-sentB: y are some of the toughest in the United States.
#
# -----from 1133 ---- to prevPoint 1228
# -----to nextPoint 1449
# OrigSent:
#   888 10728 The entrance standards to the Academy are some of the toughest in the United States. 1072 11579 Training includes many hours of learning in courses such as firearms, Constitutional law, patrol procedures, criminal behavior, high_speed pursuit and various other criminal justice and social science courses.
#
# sentA: 888 10728 The entrance standards to the Academy are some of the toughest in the United States .
#
# jaccard_measure: 0.3125
# i: 15 score: 0.3125 maxScore: 0.8823529411764706
# frag-sentA:  are some of the toughest in the United States .
# frag-sentB: her criminal justice and social science courses.
#
# maxScore 0.8823529411764706
# Final 15
# jaccard_measure: 0.8823529411764706
# Sentence 15 score max: 0.8823529411764706 offsetB: 1133 lengthB: 95
#
# sent original:  888 10728 The entrance standards to the Academy are some of the toughest in the United States.
#
# sent process: 888 10728 The entrance standards to the Academy are some of the toughest in the United States .
#
# ***************
# -----from 1228 ---- to prevPoint 1228
# -----to nextPoint 1449
# OrigSent:
#   1072 11579 Training includes many hours of learning in courses such as firearms, Constitutional law, patrol procedures, criminal behavior, high_speed pursuit and various other criminal justice and social science courses.
#
# sentA: 1072 11579 Training includes many hours of learning in courses such as firearms Constitutional law patrol procedures criminal behavior high_speed pursuit and various other criminal justice and social science courses .
#
# jaccard_measure: 0.9032258064516129
# i: 16 score: 0.9032258064516129 maxScore: 0
# frag-sentA: cedures criminal behavior high_speed pursuit and various other criminal justice and social science courses .
# frag-sentB: edures, criminal behavior, high_speed pursuit and various other criminal justice and social science courses.
#
# -----from 1228 ---- to prevPoint 1449
# -----to nextPoint 1649
# OrigSent:
#   1072 11579 Training includes many hours of learning in courses such as firearms, Constitutional law, patrol procedures, criminal behavior, high_speed pursuit and various other criminal justice and social science courses. 1157 136710 The training program at the MCJA is nearly as rigorous as the actual job itself, giving new recruits a good idea of the intensity of the demanding profession for which they are preparing.
#
# sentA: 1072 11579 Training includes many hours of learning in courses such as firearms Constitutional law patrol procedures criminal behavior high_speed pursuit and various other criminal justice and social science courses .
#
# jaccard_measure: 0.42424242424242425
# i: 16 score: 0.42424242424242425 maxScore: 0.9032258064516129
# frag-sentA: cedures criminal behavior high_speed pursuit and various other criminal justice and social science courses .
# frag-sentB: , giving new recruits a good idea of the intensity of the demanding profession for which they are preparing.
#
# maxScore 0.9032258064516129
# Final 16
# jaccard_measure: 0.9032258064516129
# Sentence 16 score max: 0.9032258064516129 offsetB: 1228 lengthB: 221
#
# sent original:  1072 11579 Training includes many hours of learning in courses such as firearms, Constitutional law, patrol procedures, criminal behavior, high-speed pursuit and various other criminal justice and social science courses.
#
# sent process: 1072 11579 Training includes many hours of learning in courses such as firearms Constitutional law patrol procedures criminal behavior high_speed pursuit and various other criminal justice and social science courses .
#
# ***************
# -----from 1449 ---- to prevPoint 1449
# -----to nextPoint 1649
# OrigSent:
#   1157 136710 The training program at the MCJA is nearly as rigorous as the actual job itself, giving new recruits a good idea of the intensity of the demanding profession for which they are preparing.
#
# sentA: 1157 136710 The training program at the MCJA is nearly as rigorous as the actual job itself giving new recruits a good idea of the intensity of the demanding profession for which they are preparing .
#
# jaccard_measure: 0.8571428571428571
# i: 17 score: 0.8571428571428571 maxScore: 0
# frag-sentA: new recruits a good idea of the intensity of the demanding profession for which they are preparing .
# frag-sentB:  new recruits a good idea of the intensity of the demanding profession for which they are preparing.
#
# -----from 1449 ---- to prevPoint 1649
# -----to nextPoint 1784
# OrigSent:
#   1157 136710 The training program at the MCJA is nearly as rigorous as the actual job itself, giving new recruits a good idea of the intensity of the demanding profession for which they are preparing. 1367 155511 After graduation from the MCJA the troopers receive a further 8 weeks of training in State police policies and procedures.
#
# sentA: 1157 136710 The training program at the MCJA is nearly as rigorous as the actual job itself giving new recruits a good idea of the intensity of the demanding profession for which they are preparing .
#
# jaccard_measure: 0.5263157894736842
# i: 17 score: 0.5263157894736842 maxScore: 0.8571428571428571
# frag-sentA: new recruits a good idea of the intensity of the demanding profession for which they are preparing .
# frag-sentB: the MCJA the troopers receive a further 8 weeks of training in State police policies and procedures.
#
# maxScore 0.8571428571428571
# Final 17
# jaccard_measure: 0.8571428571428571
# Sentence 17 score max: 0.8571428571428571 offsetB: 1449 lengthB: 200
#
# sent original:  1157 136710 The training program at the MCJA is nearly as rigorous as the actual job itself, giving new recruits a good idea of the intensity of the demanding profession for which they are preparing.
#
# sent process: 1157 136710 The training program at the MCJA is nearly as rigorous as the actual job itself giving new recruits a good idea of the intensity of the demanding profession for which they are preparing .
#
# ***************
# -----from 1649 ---- to prevPoint 1649
# -----to nextPoint 1784
# OrigSent:
#   1367 155511 After graduation from the MCJA the troopers receive a further 8 weeks of training in State police policies and procedures.
#
# sentA: 1367 155511 After graduation from the MCJA the troopers receive a further 8 weeks of training in State police policies and procedures .
#
# jaccard_measure: 0.9545454545454546
# i: 18 score: 0.9545454545454546 maxScore: 0
# frag-sentA: urther 8 weeks of training in State police policies and procedures .
# frag-sentB: further 8 weeks of training in State police policies and procedures.
#
# -----from 1649 ---- to prevPoint 1784
# -----to nextPoint 1920
# OrigSent:
#   1367 155511 After graduation from the MCJA the troopers receive a further 8 weeks of training in State police policies and procedures. 1555 167912 As Troopers progress in their careers, they are able to join other specialized units, such as the Tactical Team or K9 Unit.
#
# sentA: 1367 155511 After graduation from the MCJA the troopers receive a further 8 weeks of training in State police policies and procedures .
#
# jaccard_measure: 0.45652173913043476
# i: 18 score: 0.45652173913043476 maxScore: 0.9545454545454546
# frag-sentA: urther 8 weeks of training in State police policies and procedures .
# frag-sentB:  join other specialized units, such as the Tactical Team or K9 Unit.
#
# maxScore 0.9545454545454546
# Final 18
# jaccard_measure: 0.9545454545454546
# Sentence 18 score max: 0.9545454545454546 offsetB: 1649 lengthB: 135
#
# sent original:  1367 155511 After graduation from the MCJA the troopers receive a further 8 weeks of training in State police policies and procedures.
#
# sent process: 1367 155511 After graduation from the MCJA the troopers receive a further 8 weeks of training in State police policies and procedures .
#
# ***************
# -----from 1784 ---- to prevPoint 1784
# -----to nextPoint 1920
# OrigSent:
#   1555 167912 As Troopers progress in their careers, they are able to join other specialized units, such as the Tactical Team or K9 Unit.
#
# sentA: 1555 167912 As Troopers progress in their careers they are able to join other specialized units such as the Tactical Team or K9 Unit .
#
# jaccard_measure: 1.0
# i: 19 score: 1.0 maxScore: 0
# frag-sentA: join other specialized units such as the Tactical Team or K9 Unit .
# frag-sentB: join other specialized units, such as the Tactical Team or K9 Unit.
#
# -----from 1784 ---- to prevPoint 1920
# -----to nextPoint 1988
# OrigSent:
#   1555 167912 As Troopers progress in their careers, they are able to join other specialized units, such as the Tactical Team or K9 Unit. 1679 180213 These added units require many extra hours of training.
#
# sentA: 1555 167912 As Troopers progress in their careers they are able to join other specialized units such as the Tactical Team or K9 Unit .
#
# jaccard_measure: 0.6857142857142857
# i: 19 score: 0.6857142857142857 maxScore: 1.0
# frag-sentA: join other specialized units such as the Tactical Team or K9 Unit .
# frag-sentB: 1679 180213 These added units require many extra hours of training.
#
# maxScore 1.0
# Final 19
# jaccard_measure: 1.0
# Sentence 19 score max: 1.0 offsetB: 1784 lengthB: 136
#
# sent original:  1555 167912 As Troopers progress in their careers, they are able to join other specialized units, such as the Tactical Team or K9 Unit.
#
# sent process: 1555 167912 As Troopers progress in their careers they are able to join other specialized units such as the Tactical Team or K9 Unit .
#
# ***************
# -----from 1920 ---- to prevPoint 1920
# -----to nextPoint 1988
# OrigSent:
#   1679 180213 These added units require many extra hours of training.
#
# sentA: 1679 180213 These added units require many extra hours of training .
#
# jaccard_measure: 1.0
# i: 20 score: 1.0 maxScore: 0
# frag-sentA: ire many extra hours of training .
# frag-sentB: uire many extra hours of training.
#
# -----from 1920 ---- to prevPoint 1988
# -----to nextPoint 2101
# OrigSent:
#   1679 180213 These added units require many extra hours of training. 1802 185814 Many State Troopers are involved in two to three extra units, depending upon where they are located.
#
# sentA: 1679 180213 These added units require many extra hours of training .
#
# jaccard_measure: 0.36666666666666664
# i: 20 score: 0.36666666666666664 maxScore: 1.0
# frag-sentA: ire many extra hours of training .
# frag-sentB: nding upon where they are located.
#
# maxScore 1.0
# Final 20
# jaccard_measure: 1.0
# Sentence 20 score max: 1.0 offsetB: 1920 lengthB: 68
#
# sent original:  1679 180213 These added units require many extra hours of training.
#
# sent process: 1679 180213 These added units require many extra hours of training .
#
# ***************
# -----from 1988 ---- to prevPoint 1988
# -----to nextPoint 2101
# OrigSent:
#   1802 185814 Many State Troopers are involved in two to three extra units, depending upon where they are located.
#
# sentA: 1802 185814 Many State Troopers are involved in two to three extra units depending upon where they are located .
#
# jaccard_measure: 0.9473684210526315
# i: 21 score: 0.9473684210526315 maxScore: 0
# frag-sentA: hree extra units depending upon where they are located .
# frag-sentB: hree extra units, depending upon where they are located.
#
# -----from 1988 ---- to prevPoint 2101
# -----to nextPoint 2135
# OrigSent:
#   1802 185814 Many State Troopers are involved in two to three extra units, depending upon where they are located. 1858 195915 [] edit Field Troops.
#
# sentA: 1802 185814 Many State Troopers are involved in two to three extra units depending upon where they are located .
#
# jaccard_measure: 0.75
# i: 21 score: 0.75 maxScore: 0.9473684210526315
# frag-sentA: hree extra units depending upon where they are located .
# frag-sentB: here they are located. 1858 195915 [] edit Field Troops.
#
# maxScore 0.9473684210526315
# Final 21
# jaccard_measure: 0.9473684210526315
# Sentence 21 score max: 0.9473684210526315 offsetB: 1988 lengthB: 113
#
# sent original:  1802 185814 Many State Troopers are involved in two to three extra units, depending upon where they are located.
#
# sent process: 1802 185814 Many State Troopers are involved in two to three extra units depending upon where they are located .
#
# ***************
# -----from 2101 ---- to prevPoint 2101
# -----to nextPoint 2135
# OrigSent:
#   1858 195915 [] edit Field Troops.
#
# sentA: 1858 195915 edit Field Troops .
#
# jaccard_measure: 1.0
# i: 22 score: 1.0 maxScore: 0
# frag-sentA: t Field Troops .
# frag-sentB: it Field Troops.
#
# -----from 2101 ---- to prevPoint 2135
# -----to nextPoint 2278
# OrigSent:
#   1858 195915 [] edit Field Troops.Maine's State Police Officers (more commonly referred to as "State Troopers" by the locals) patrol from nine barracks located across the state.
#
# sentA: 1858 195915 edit Field Troops .
#
# jaccard_measure: 0.17857142857142858
# i: 22 score: 0.17857142857142858 maxScore: 1.0
# frag-sentA: t Field Troops .
# frag-sentB: cross the state.
#
# maxScore 1.0
# Final 22
# jaccard_measure: 1.0
# Sentence 22 score max: 1.0 offsetB: 2101 lengthB: 34
#
# sent original:  1858 195915 [] edit Field Troops
#
#
# sent process: 1858 195915 edit Field Troops .
#
# ***************
# -----from 2135 ---- to prevPoint 2135
# -----to nextPoint 2278
# OrigSent:
#  Maine's State Police Officers (more commonly referred to as "State Troopers" by the locals) patrol from nine barracks located across the state.
#
# sentA: Maine is State Police Officers more commonly referred to as State Troopers by the locals patrol from nine barracks located across the state .
#
# jaccard_measure: 0.8695652173913043
# i: 23 score: 0.8695652173913043 maxScore: 0
# frag-sentA: ers by the locals patrol from nine barracks located across the state .
# frag-sentB: rs" by the locals) patrol from nine barracks located across the state.
#
# -----from 2135 ---- to prevPoint 2278
# -----to nextPoint 2327
# OrigSent:
#  Maine's State Police Officers (more commonly referred to as "State Troopers" by the locals) patrol from nine barracks located across the state. 1959 212416 Dubbed "Troops," these barracks are.
#
# sentA: Maine is State Police Officers more commonly referred to as State Troopers by the locals patrol from nine barracks located across the state .
#
# jaccard_measure: 0.6666666666666666
# i: 23 score: 0.6666666666666666 maxScore: 0.8695652173913043
# frag-sentA: ers by the locals patrol from nine barracks located across the state .
# frag-sentB: ted across the state. 1959 212416 Dubbed "Troops," these barracks are.
#
# maxScore 0.8695652173913043
# Final 23
# jaccard_measure: 0.8695652173913043
# Sentence 23 score max: 0.8695652173913043 offsetB: 2135 lengthB: 143
#
# sent original: Maine's State Police Officers (more commonly referred to as "State Troopers" by the locals) patrol from nine barracks located across the state.
#
# sent process: Maine is State Police Officers more commonly referred to as State Troopers by the locals patrol from nine barracks located across the state .
#
# ***************
# -----from 2278 ---- to prevPoint 2278
# -----to nextPoint 2327
# OrigSent:
#   1959 212416 Dubbed "Troops," these barracks are.
#
# sentA: 1959 212416 Dubbed Troops these barracks are .
#
# jaccard_measure: 1.0
# i: 24 score: 1.0 maxScore: 0
# frag-sentA: ps these barracks are .
# frag-sentB: s," these barracks are.
#
# -----from 2278 ---- to prevPoint 2327
# -----to nextPoint 2328
# OrigSent:
#   1959 212416 Dubbed "Troops," these barracks are..
#
# sentA: 1959 212416 Dubbed Troops these barracks are .
#
# jaccard_measure: 1.0
# i: 24 score: 1.0 maxScore: 1.0
# frag-sentA: ps these barracks are .
# frag-sentB: ," these barracks are..
#
# -----from 2278 ---- to prevPoint 2328
# -----to nextPoint 2359
# OrigSent:
#   1959 212416 Dubbed "Troops," these barracks are..Troop A - Alfred - York County.
#
# sentA: 1959 212416 Dubbed Troops these barracks are .
#
# jaccard_measure: 0.5833333333333334
# i: 24 score: 0.5833333333333334 maxScore: 1.0
# frag-sentA: ps these barracks are .
# frag-sentB: - Alfred - York County.
#
# maxScore 1.0
# Final 24
# jaccard_measure: 1.0
# Sentence 24 score max: 1.0 offsetB: 2278 lengthB: 50
#
# sent original:  1959 212416 Dubbed "Troops," these barracks are:
#
#
# sent process: 1959 212416 Dubbed Troops these barracks are .
#
# ***************
# -----from 2328 ---- to prevPoint 2328
# -----to nextPoint 2359
# OrigSent:
#  Troop A - Alfred - York County.
#
# sentA: Troop A Alfred York County .
#
# jaccard_measure: 1.0
# i: 25 score: 1.0 maxScore: 0
# frag-sentA:  York County .
# frag-sentB: - York County.
#
# -----from 2328 ---- to prevPoint 2359
# -----to nextPoint 2391
# OrigSent:
#  Troop A - Alfred - York County.Troop B - Gray - Southern Maine.
#
# sentA: Troop A Alfred York County .
#
# jaccard_measure: 0.5
# i: 25 score: 0.5 maxScore: 1.0
# frag-sentA:  York County .
# frag-sentB: outhern Maine.
#
# maxScore 1.0
# Final 25
# jaccard_measure: 1.0
# Sentence 25 score max: 1.0 offsetB: 2328 lengthB: 31
#
# sent original: Troop A - Alfred - York County
#
#
# sent process: Troop A Alfred York County .
#
# ***************
# -----from 2359 ---- to prevPoint 2359
# -----to nextPoint 2391
# OrigSent:
#  Troop B - Gray - Southern Maine.
#
# sentA: Troop B Gray Southern Maine .
#
# jaccard_measure: 1.0
# i: 26 score: 1.0 maxScore: 0
# frag-sentA: uthern Maine .
# frag-sentB: outhern Maine.
#
# -----from 2359 ---- to prevPoint 2391
# -----to nextPoint 2427
# OrigSent:
#  Troop B - Gray - Southern Maine.Troop C - Skowhegan - Western Maine.
#
# sentA: Troop B Gray Southern Maine .
#
# jaccard_measure: 0.5
# i: 26 score: 0.5 maxScore: 1.0
# frag-sentA: uthern Maine .
# frag-sentB: Western Maine.
#
# maxScore 1.0
# Final 26
# jaccard_measure: 1.0
# Sentence 26 score max: 1.0 offsetB: 2359 lengthB: 32
#
# sent original: Troop B - Gray - Southern Maine
#
#
# sent process: Troop B Gray Southern Maine .
#
# ***************
# -----from 2391 ---- to prevPoint 2391
# -----to nextPoint 2427
# OrigSent:
#  Troop C - Skowhegan - Western Maine.
#
# sentA: Troop C Skowhegan Western Maine .
#
# jaccard_measure: 1.0
# i: 27 score: 1.0 maxScore: 0
# frag-sentA:  Western Maine .
# frag-sentB: - Western Maine.
#
# -----from 2391 ---- to prevPoint 2427
# -----to nextPoint 2464
# OrigSent:
#  Troop C - Skowhegan - Western Maine.Troop D - Thomaston - Midcoast Maine.
#
# sentA: Troop C Skowhegan Western Maine .
#
# jaccard_measure: 0.5
# i: 27 score: 0.5 maxScore: 1.0
# frag-sentA:  Western Maine .
# frag-sentB:  Midcoast Maine.
#
# maxScore 1.0
# Final 27
# jaccard_measure: 1.0
# Sentence 27 score max: 1.0 offsetB: 2391 lengthB: 36
#
# sent original: Troop C - Skowhegan - Western Maine
#
#
# sent process: Troop C Skowhegan Western Maine .
#
# ***************
# -----from 2427 ---- to prevPoint 2427
# -----to nextPoint 2464
# OrigSent:
#  Troop D - Thomaston - Midcoast Maine.
#
# sentA: Troop D Thomaston Midcoast Maine .
#
# jaccard_measure: 1.0
# i: 28 score: 1.0 maxScore: 0
# frag-sentA:  Midcoast Maine .
# frag-sentB: - Midcoast Maine.
#
# -----from 2427 ---- to prevPoint 2464
# -----to nextPoint 2496
# OrigSent:
#  Troop D - Thomaston - Midcoast Maine.Troop E - Orono - Central Maine.
#
# sentA: Troop D Thomaston Midcoast Maine .
#
# jaccard_measure: 0.5
# i: 28 score: 0.5 maxScore: 1.0
# frag-sentA:  Midcoast Maine .
# frag-sentB:  - Central Maine.
#
# maxScore 1.0
# Final 28
# jaccard_measure: 1.0
# Sentence 28 score max: 1.0 offsetB: 2427 lengthB: 37
#
# sent original: Troop D - Thomaston - Midcoast Maine
#
#
# sent process: Troop D Thomaston Midcoast Maine .
#
# ***************
# -----from 2464 ---- to prevPoint 2464
# -----to nextPoint 2496
# OrigSent:
#  Troop E - Orono - Central Maine.
#
# sentA: Troop E Orono Central Maine .
#
# jaccard_measure: 1.0
# i: 29 score: 1.0 maxScore: 0
# frag-sentA: entral Maine .
# frag-sentB: Central Maine.
#
# -----from 2464 ---- to prevPoint 2496
# -----to nextPoint 2531
# OrigSent:
#  Troop E - Orono - Central Maine.Troop F - Houlton - Northern Maine.
#
# sentA: Troop E Orono Central Maine .
#
# jaccard_measure: 0.5
# i: 29 score: 0.5 maxScore: 1.0
# frag-sentA: entral Maine .
# frag-sentB: orthern Maine.
#
# maxScore 1.0
# Final 29
# jaccard_measure: 1.0
# Sentence 29 score max: 1.0 offsetB: 2464 lengthB: 32
#
# sent original: Troop E - Orono - Central Maine
#
#
# sent process: Troop E Orono Central Maine .
#
# ***************
# -----from 2496 ---- to prevPoint 2496
# -----to nextPoint 2531
# OrigSent:
#  Troop F - Houlton - Northern Maine.
#
# sentA: Troop F Houlton Northern Maine .
#
# jaccard_measure: 1.0
# i: 30 score: 1.0 maxScore: 0
# frag-sentA: Northern Maine .
# frag-sentB:  Northern Maine.
#
# -----from 2496 ---- to prevPoint 2531
# -----to nextPoint 2573
# OrigSent:
#  Troop F - Houlton - Northern Maine.Troop G - South Portland - Maine Turnpike.
#
# sentA: Troop F Houlton Northern Maine .
#
# jaccard_measure: 0.45454545454545453
# i: 30 score: 0.45454545454545453 maxScore: 1.0
# frag-sentA: Northern Maine .
# frag-sentB:  Maine Turnpike.
#
# maxScore 1.0
# Final 30
# jaccard_measure: 1.0
# Sentence 30 score max: 1.0 offsetB: 2496 lengthB: 35
#
# sent original: Troop F - Houlton - Northern Maine
#
#
# sent process: Troop F Houlton Northern Maine .
#
# ***************
# -----from 2531 ---- to prevPoint 2531
# -----to nextPoint 2573
# OrigSent:
#  Troop G - South Portland - Maine Turnpike.
#
# sentA: Troop G South Portland Maine Turnpike .
#
# jaccard_measure: 1.0
# i: 31 score: 1.0 maxScore: 0
# frag-sentA: and Maine Turnpike .
# frag-sentB: nd - Maine Turnpike.
#
# -----from 2531 ---- to prevPoint 2573
# -----to nextPoint 2610
# OrigSent:
#  Troop G - South Portland - Maine Turnpike.Troop J - Ellsworth - Downeast Maine.
#
# sentA: Troop G South Portland Maine Turnpike .
#
# jaccard_measure: 0.5454545454545454
# i: 31 score: 0.5454545454545454 maxScore: 1.0
# frag-sentA: and Maine Turnpike .
# frag-sentB: th - Downeast Maine.
#
# maxScore 1.0
# Final 31
# jaccard_measure: 1.0
# Sentence 31 score max: 1.0 offsetB: 2531 lengthB: 42
#
# sent original: Troop G - South Portland - Maine Turnpike
#
#
# sent process: Troop G South Portland Maine Turnpike .
#
# ***************
# -----from 2573 ---- to prevPoint 2573
# -----to nextPoint 2610
# OrigSent:
#  Troop J - Ellsworth - Downeast Maine.
#
# sentA: Troop J Ellsworth Downeast Maine .
#
# jaccard_measure: 1.0
# i: 32 score: 1.0 maxScore: 0
# frag-sentA:  Downeast Maine .
# frag-sentB: - Downeast Maine.
#
# -----from 2573 ---- to prevPoint 2610
# -----to nextPoint 2726
# OrigSent:
#  Troop J - Ellsworth - Downeast Maine.Troop K is composed of sworn Troopers that enforce the motor vehicle guideline laws set forth by the State of Maine.
#
# sentA: Troop J Ellsworth Downeast Maine .
#
# jaccard_measure: 0.19230769230769232
# i: 32 score: 0.19230769230769232 maxScore: 1.0
# frag-sentA:  Downeast Maine .
# frag-sentB: e State of Maine.
#
# maxScore 1.0
# Final 32
# jaccard_measure: 1.0
# Sentence 32 score max: 1.0 offsetB: 2573 lengthB: 37
#
# sent original: Troop J - Ellsworth - Downeast Maine
#
#
# sent process: Troop J Ellsworth Downeast Maine .
#
# ***************
# -----from 2610 ---- to prevPoint 2610
# -----to nextPoint 2726
# OrigSent:
#  Troop K is composed of sworn Troopers that enforce the motor vehicle guideline laws set forth by the State of Maine.
#
# sentA: Troop K is composed of sworn Troopers that enforce the motor vehicle guideline laws set forth by the State of Maine .
#
# jaccard_measure: 0.9047619047619048
# i: 33 score: 0.9047619047619048 maxScore: 0
# frag-sentA: r vehicle guideline laws set forth by the State of Maine .
# frag-sentB: or vehicle guideline laws set forth by the State of Maine.
#
# -----from 2610 ---- to prevPoint 2726
# -----to nextPoint 2834
# OrigSent:
#  Troop K is composed of sworn Troopers that enforce the motor vehicle guideline laws set forth by the State of Maine. 2124 256017 These Troopers are members of the unit, and are based out of the state's capital city, Augusta.
#
# sentA: Troop K is composed of sworn Troopers that enforce the motor vehicle guideline laws set forth by the State of Maine .
#
# jaccard_measure: 0.4634146341463415
# i: 33 score: 0.4634146341463415 maxScore: 0.9047619047619048
# frag-sentA: r vehicle guideline laws set forth by the State of Maine .
# frag-sentB: t, and are based out of the state's capital city, Augusta.
#
# maxScore 0.9047619047619048
# Final 33
# jaccard_measure: 0.9047619047619048
# Sentence 33 score max: 0.9047619047619048 offsetB: 2610 lengthB: 116
#
# sent original: Troop K is composed of sworn Troopers that enforce the motor vehicle guideline laws set forth by the State of Maine.
#
# sent process: Troop K is composed of sworn Troopers that enforce the motor vehicle guideline laws set forth by the State of Maine .
#
# ***************
# -----from 2726 ---- to prevPoint 2726
# -----to nextPoint 2834
# OrigSent:
#   2124 256017 These Troopers are members of the unit, and are based out of the state's capital city, Augusta.
#
# sentA: 2124 256017 These Troopers are members of the unit and are based out of the state is capital city Augusta .
#
# jaccard_measure: 0.8
# i: 34 score: 0.8 maxScore: 0
# frag-sentA: d are based out of the state is capital city Augusta .
# frag-sentB: nd are based out of the state's capital city, Augusta.
#
# -----from 2726 ---- to prevPoint 2834
# -----to nextPoint 2877
# OrigSent:
#   2124 256017 These Troopers are members of the unit, and are based out of the state's capital city, Augusta. 2560 268718 ommercial Vehicle Enforcement.
#
# sentA: 2124 256017 These Troopers are members of the unit and are based out of the state is capital city Augusta .
#
# jaccard_measure: 0.64
# i: 34 score: 0.64 maxScore: 0.8
# frag-sentA: d are based out of the state is capital city Augusta .
# frag-sentB: y, Augusta. 2560 268718 ommercial Vehicle Enforcement.
#
# maxScore 0.8
# Final 34
# jaccard_measure: 0.8
# Sentence 34 score max: 0.8 offsetB: 2726 lengthB: 108
#
# sent original:  2124 256017 These Troopers are members of the unit, and are based out of the state's capital city, Augusta.
#
# sent process: 2124 256017 These Troopers are members of the unit and are based out of the state is capital city Augusta .
#
# ***************
# -----from 2834 ---- to prevPoint 2834
# -----to nextPoint 2877
# OrigSent:
#   2560 268718 ommercial Vehicle Enforcement.
#
# sentA: 2560 268718 ommercial Vehicle Enforcement .
#
# jaccard_measure: 1.0
# i: 35 score: 1.0 maxScore: 0
# frag-sentA:  Vehicle Enforcement .
# frag-sentB: l Vehicle Enforcement.
#
# -----from 2834 ---- to prevPoint 2877
# -----to nextPoint 2923
# OrigSent:
#   2560 268718 ommercial Vehicle Enforcement.Maine State Police Cruiser - Ford Interceptor.
#
# sentA: 2560 268718 ommercial Vehicle Enforcement .
#
# jaccard_measure: 0.45454545454545453
# i: 35 score: 0.45454545454545453 maxScore: 1.0
# frag-sentA:  Vehicle Enforcement .
# frag-sentB: er - Ford Interceptor.
#
# maxScore 1.0
# Final 35
# jaccard_measure: 1.0
# Sentence 35 score max: 1.0 offsetB: 2834 lengthB: 43
#
# sent original:  2560 268718 ommercial Vehicle Enforcement
#
#
# sent process: 2560 268718 ommercial Vehicle Enforcement .
#
# ***************
# -----from 2877 ---- to prevPoint 2877
# -----to nextPoint 2923
# OrigSent:
#  Maine State Police Cruiser - Ford Interceptor.
#
# sentA: Maine State Police Cruiser Ford Interceptor .
#
# jaccard_measure: 1.0
# i: 36 score: 1.0 maxScore: 0
# frag-sentA: ser Ford Interceptor .
# frag-sentB: er - Ford Interceptor.
#
# -----from 2877 ---- to prevPoint 2923
# -----to nextPoint 2968
# OrigSent:
#  Maine State Police Cruiser - Ford Interceptor.The State Police have many specialized units.
#
# sentA: Maine State Police Cruiser Ford Interceptor .
#
# jaccard_measure: 0.46153846153846156
# i: 36 score: 0.46153846153846156 maxScore: 1.0
# frag-sentA: ser Ford Interceptor .
# frag-sentB: any specialized units.
#
# maxScore 1.0
# Final 36
# jaccard_measure: 1.0
# Sentence 36 score max: 1.0 offsetB: 2877 lengthB: 46
#
# sent original: Maine State Police Cruiser - Ford Interceptor
#
#
# sent process: Maine State Police Cruiser Ford Interceptor .
#
# ***************
# -----from 2923 ---- to prevPoint 2923
# -----to nextPoint 2968
# OrigSent:
#  The State Police have many specialized units.
#
# sentA: The State Police have many specialized units .
#
# jaccard_measure: 1.0
# i: 37 score: 1.0 maxScore: 0
# frag-sentA: any specialized units .
# frag-sentB: many specialized units.
#
# -----from 2923 ---- to prevPoint 2968
# -----to nextPoint 2995
# OrigSent:
#  The State Police have many specialized units. 2687 277819 These include.
#
# sentA: The State Police have many specialized units .
#
# jaccard_measure: 0.6363636363636364
# i: 37 score: 0.6363636363636364 maxScore: 1.0
# frag-sentA: any specialized units .
# frag-sentB: 7 277819 These include.
#
# maxScore 1.0
# Final 37
# jaccard_measure: 1.0
# Sentence 37 score max: 1.0 offsetB: 2923 lengthB: 45
#
# sent original: The State Police have many specialized units.
#
# sent process: The State Police have many specialized units .
#
# ***************
# -----from 2968 ---- to prevPoint 2968
# -----to nextPoint 2995
# OrigSent:
#   2687 277819 These include.
#
# sentA: 2687 277819 These include .
#
# jaccard_measure: 1.0
# i: 38 score: 1.0 maxScore: 0
# frag-sentA: hese include .
# frag-sentB: These include.
#
# -----from 2968 ---- to prevPoint 2995
# -----to nextPoint 3013
# OrigSent:
#   2687 277819 These include.
# [] edit Air Wing.
#
# sentA: 2687 277819 These include .
#
# jaccard_measure: 0.5714285714285714
# i: 38 score: 0.5714285714285714 maxScore: 1.0
# frag-sentA: hese include .
# frag-sentB: edit Air Wing.
#
# maxScore 1.0
# Final 38
# jaccard_measure: 1.0
# Sentence 38 score max: 1.0 offsetB: 2968 lengthB: 27
#
# sent original:  2687 277819 These include:
#
# sent process: 2687 277819 These include .
#
# ***************
# -----from 2995 ---- to prevPoint 2995
# -----to nextPoint 3013
# OrigSent:
#
# [] edit Air Wing.
#
# sentA: edit Air Wing .
#
# jaccard_measure: 1.0
# i: 39 score: 1.0 maxScore: 0
# frag-sentA: r Wing .
# frag-sentB: ir Wing.
#
# -----from 2995 ---- to prevPoint 3013
# -----to nextPoint 3074
# OrigSent:
#
# [] edit Air Wing.The Maine State Police Air Wing was established in the 1970s.
#
# sentA: edit Air Wing .
#
# jaccard_measure: 0.21428571428571427
# i: 39 score: 0.21428571428571427 maxScore: 1.0
# frag-sentA: r Wing .
# frag-sentB: e 1970s.
#
# maxScore 1.0
# Final 39
# jaccard_measure: 1.0
# ...
#
# jaccard_measure: 0.4838709677419355
# i: 123 score: 0.4838709677419355 maxScore: 0.9375
# frag-sentA: nspection mechanics and 2 400 inspection stations .
# frag-sentB: ectors, and two clerks currently staff the program.
#
# maxScore 0.9375
# Final 123
# jaccard_measure: 0.9375
# Sentence 123 score max: 0.9375 offsetB: 10710 lengthB: 102
#
# sent original:  3106 327291 There are about 7,500 active licensed inspection mechanics and 2,400 inspection stations.
#
# sent process: 3106 327291 There are about 7 500 active licensed inspection mechanics and 2 400 inspection stations .
#
# ***************
# -----from 10812 ---- to prevPoint 10812
# -----to nextPoint 10912
# OrigSent:
#   3272 357392 One sergeant, ten motor vehicle inspectors, and two clerks currently staff the program.
#
# sentA: 3272 357392 One sergeant ten motor vehicle inspectors and two clerks currently staff the program .
#
# jaccard_measure: 1.0
# i: 124 score: 1.0 maxScore: 0
# frag-sentA: tors and two clerks currently staff the program .
# frag-sentB: tors, and two clerks currently staff the program.
#
# -----from 10812 ---- to prevPoint 10912
# -----to nextPoint 10975
# OrigSent:
#   3272 357392 One sergeant, ten motor vehicle inspectors, and two clerks currently staff the program. 3573 375193 [] edit Motor Vehicle Crash Investigation Program.
#
# sentA: 3272 357392 One sergeant ten motor vehicle inspectors and two clerks currently staff the program .
#
# jaccard_measure: 0.6521739130434783
# i: 124 score: 0.6521739130434783 maxScore: 1.0
# frag-sentA: tors and two clerks currently staff the program .
# frag-sentB: ] edit Motor Vehicle Crash Investigation Program.
#
# maxScore 1.0
# Final 124
# jaccard_measure: 1.0
# Sentence 124 score max: 1.0 offsetB: 10812 lengthB: 100
#
# sent original:  3272 357392 One sergeant, ten motor vehicle inspectors, and two clerks currently staff the program.
#
# sent process: 3272 357392 One sergeant ten motor vehicle inspectors and two clerks currently staff the program .
#
# ***************
# -----from 10912 ---- to prevPoint 10912
# -----to nextPoint 10975
# OrigSent:
#   3573 375193 [] edit Motor Vehicle Crash Investigation Program.
#
# sentA: 3573 375193 edit Motor Vehicle Crash Investigation Program .
#
# jaccard_measure: 1.0
# i: 125 score: 1.0 maxScore: 0
# frag-sentA:  Crash Investigation Program .
# frag-sentB: e Crash Investigation Program.
#
# -----from 10912 ---- to prevPoint 10975
# -----to nextPoint 11096
# OrigSent:
#   3573 375193 [] edit Motor Vehicle Crash Investigation Program.The State of Maine Crash Reconstruction Unit is composed of State Police, Municipal and County Law Enforcement personnel.
#
# sentA: 3573 375193 edit Motor Vehicle Crash Investigation Program .
#
# jaccard_measure: 0.3076923076923077
# i: 125 score: 0.3076923076923077 maxScore: 1.0
# frag-sentA:  Crash Investigation Program .
# frag-sentB: nty Law Enforcement personnel.
#
# maxScore 1.0
# Final 125
# jaccard_measure: 1.0
# Sentence 125 score max: 1.0 offsetB: 10912 lengthB: 63
#
# sent original:  3573 375193 [] edit Motor Vehicle Crash Investigation Program
#
#
# sent process: 3573 375193 edit Motor Vehicle Crash Investigation Program .
#
# ***************
# -----from 10975 ---- to prevPoint 10975
# -----to nextPoint 11096
# OrigSent:
#  The State of Maine Crash Reconstruction Unit is composed of State Police, Municipal and County Law Enforcement personnel.
#
# sentA: The State of Maine Crash Reconstruction Unit is composed of State Police Municipal and County Law Enforcement personnel .
#
# jaccard_measure: 0.8888888888888888
# i: 126 score: 0.8888888888888888 maxScore: 0
# frag-sentA: tate Police Municipal and County Law Enforcement personnel .
# frag-sentB: tate Police, Municipal and County Law Enforcement personnel.
#
# -----from 10975 ---- to prevPoint 11096
# -----to nextPoint 11186
# OrigSent:
#  The State of Maine Crash Reconstruction Unit is composed of State Police, Municipal and County Law Enforcement personnel. 3751 386494 Currently the unit includes 20 Troopers, 15 County and 37 Municipal officers.
#
# sentA: The State of Maine Crash Reconstruction Unit is composed of State Police Municipal and County Law Enforcement personnel .
#
# jaccard_measure: 0.5
# i: 126 score: 0.5 maxScore: 0.8888888888888888
# frag-sentA: tate Police Municipal and County Law Enforcement personnel .
# frag-sentB: t includes 20 Troopers, 15 County and 37 Municipal officers.
#
# maxScore 0.8888888888888888
# Final 126
# jaccard_measure: 0.8888888888888888
# Sentence 126 score max: 0.8888888888888888 offsetB: 10975 lengthB: 121
#
# sent original: The State of Maine Crash Reconstruction Unit is composed of State Police, Municipal and County Law Enforcement personnel.
#
# sent process: The State of Maine Crash Reconstruction Unit is composed of State Police Municipal and County Law Enforcement personnel .
#
# ***************
# -----from 11096 ---- to prevPoint 11096
# -----to nextPoint 11186
# OrigSent:
#   3751 386494 Currently the unit includes 20 Troopers, 15 County and 37 Municipal officers.
#
# sentA: 3751 386494 Currently the unit includes 20 Troopers 15 County and 37 Municipal officers .
#
# jaccard_measure: 1.0
# i: 127 score: 1.0 maxScore: 0
# frag-sentA: oopers 15 County and 37 Municipal officers .
# frag-sentB: oopers, 15 County and 37 Municipal officers.
#
# -----from 11096 ---- to prevPoint 11186
# -----to nextPoint 11313
# OrigSent:
#   3751 386494 Currently the unit includes 20 Troopers, 15 County and 37 Municipal officers. 3864 394595 Unit members are located throughout the entire state and are chosen based on both geographic location and ability.
#
# sentA: 3751 386494 Currently the unit includes 20 Troopers 15 County and 37 Municipal officers .
#
# jaccard_measure: 0.4117647058823529
# i: 127 score: 0.4117647058823529 maxScore: 1.0
# frag-sentA: oopers 15 County and 37 Municipal officers .
# frag-sentB: sed on both geographic location and ability.
#
# maxScore 1.0
# Final 127
# jaccard_measure: 1.0
# Sentence 127 score max: 1.0 offsetB: 11096 lengthB: 90
#
# sent original:  3751 386494 Currently the unit includes 20 Troopers, 15 County and 37 Municipal officers.
#
# sent process: 3751 386494 Currently the unit includes 20 Troopers 15 County and 37 Municipal officers .
#
# ***************
# -----from 11186 ---- to prevPoint 11186
# -----to nextPoint 11313
# OrigSent:
#   3864 394595 Unit members are located throughout the entire state and are chosen based on both geographic location and ability.
#
# sentA: 3864 394595 Unit members are located throughout the entire state and are chosen based on both geographic location and ability .
#
# jaccard_measure: 0.9
# i: 128 score: 0.9 maxScore: 0
# frag-sentA: e and are chosen based on both geographic location and ability .
# frag-sentB: te and are chosen based on both geographic location and ability.
#
# -----from 11186 ---- to prevPoint 11313
# -----to nextPoint 11473
# OrigSent:
#   3864 394595 Unit members are located throughout the entire state and are chosen based on both geographic location and ability. 3945 410196 The objective of the Crash Reconstruction Unit is to conduct in_depth investigations and analyses of major traffic collisions throughout the state.
#
# sentA: 3864 394595 Unit members are located throughout the entire state and are chosen based on both geographic location and ability .
#
# jaccard_measure: 0.4090909090909091
# i: 128 score: 0.4090909090909091 maxScore: 0.9
# frag-sentA: e and are chosen based on both geographic location and ability .
# frag-sentB: s and analyses of major traffic collisions throughout the state.
#
# maxScore 0.9
# Final 128
# jaccard_measure: 0.9
# Sentence 128 score max: 0.9 offsetB: 11186 lengthB: 127
#
# sent original:  3864 394595 Unit members are located throughout the entire state and are chosen based on both geographic location and ability.
#
# sent process: 3864 394595 Unit members are located throughout the entire state and are chosen based on both geographic location and ability .
#
# ***************
# -----from 11313 ---- to prevPoint 11313
# -----to nextPoint 11473
# OrigSent:
#   3945 410196 The objective of the Crash Reconstruction Unit is to conduct in_depth investigations and analyses of major traffic collisions throughout the state.
#
# sentA: 3945 410196 The objective of the Crash Reconstruction Unit is to conduct in_depth investigations and analyses of major traffic collisions throughout the state .
#
# jaccard_measure: 0.9166666666666666
# i: 129 score: 0.9166666666666666 maxScore: 0
# frag-sentA: h investigations and analyses of major traffic collisions throughout the state .
# frag-sentB: th investigations and analyses of major traffic collisions throughout the state.
#
# -----from 11313 ---- to prevPoint 11473
# -----to nextPoint 11606
# OrigSent:
#   3945 410196 The objective of the Crash Reconstruction Unit is to conduct in_depth investigations and analyses of major traffic collisions throughout the state. 4101 420197 Investigations include the reconstruction of a crash and a study of the factors that may have contributed to that crash.
#
# sentA: 3945 410196 The objective of the Crash Reconstruction Unit is to conduct in_depth investigations and analyses of major traffic collisions throughout the state .
#
# jaccard_measure: 0.4782608695652174
# i: 129 score: 0.4782608695652174 maxScore: 0.9166666666666666
# frag-sentA: h investigations and analyses of major traffic collisions throughout the state .
# frag-sentB: n of a crash and a study of the factors that may have contributed to that crash.
#
# maxScore 0.9166666666666666
# Final 129
# jaccard_measure: 0.9166666666666666
# Sentence 129 score max: 0.9166666666666666 offsetB: 11313 lengthB: 160
#
# sent original:  3945 410196 The objective of the Crash Reconstruction Unit is to conduct in-depth investigations and analyses of major traffic collisions throughout the state.
#
# sent process: 3945 410196 The objective of the Crash Reconstruction Unit is to conduct in_depth investigations and analyses of major traffic collisions throughout the state .
#
# ***************
# -----from 11473 ---- to prevPoint 11473
# -----to nextPoint 11606
# OrigSent:
#   4101 420197 Investigations include the reconstruction of a crash and a study of the factors that may have contributed to that crash.
#
# sentA: 4101 420197 Investigations include the reconstruction of a crash and a study of the factors that may have contributed to that crash .
#
# jaccard_measure: 0.7727272727272727
# i: 130 score: 0.7727272727272727 maxScore: 0
# frag-sentA: d a study of the factors that may have contributed to that crash .
# frag-sentB: nd a study of the factors that may have contributed to that crash.
#
# -----from 11473 ---- to prevPoint 11606
# -----to nextPoint 11779
# OrigSent:
#   4101 420197 Investigations include the reconstruction of a crash and a study of the factors that may have contributed to that crash. 4201 429198 These factors include environmental, human and mechanical and are associated with the three phases of a collision, which are pre_crash, at_crash and post_crash.
#
# sentA: 4101 420197 Investigations include the reconstruction of a crash and a study of the factors that may have contributed to that crash .
#
# jaccard_measure: 0.34
# i: 130 score: 0.34 maxScore: 0.7727272727272727
# frag-sentA: d a study of the factors that may have contributed to that crash .
# frag-sentB: ases of a collision, which are pre_crash, at_crash and post_crash.
#
# maxScore 0.7727272727272727
# Final 130
# jaccard_measure: 0.7727272727272727
# Sentence 130 score max: 0.7727272727272727 offsetB: 11473 lengthB: 133
#
# sent original:  4101 420197 Investigations include the reconstruction of a crash and a study of the factors that may have contributed to that crash.
#
# sent process: 4101 420197 Investigations include the reconstruction of a crash and a study of the factors that may have contributed to that crash .
#
# ***************
# -----from 11606 ---- to prevPoint 11606
# -----to nextPoint 11779
# OrigSent:
#   4201 429198 These factors include environmental, human and mechanical and are associated with the three phases of a collision, which are pre_crash, at_crash and post_crash.
#
# sentA: 4201 429198 These factors include environmental human and mechanical and are associated with the three phases of a collision which are pre_crash at_crash and post_crash .
#
# jaccard_measure: 0.8214285714285714
# i: 131 score: 0.8214285714285714 maxScore: 0
# frag-sentA: ed with the three phases of a collision which are pre_crash at_crash and post_crash .
# frag-sentB: d with the three phases of a collision, which are pre_crash, at_crash and post_crash.
#
# -----from 11606 ---- to prevPoint 11779
# -----to nextPoint 11944
# OrigSent:
#   4201 429198 These factors include environmental, human and mechanical and are associated with the three phases of a collision, which are pre_crash, at_crash and post_crash. 4291 444999 The ultimate objective of the program is the utilization of these identified causation factors to prevent collisions of a similar nature from recurring.
#
# sentA: 4201 429198 These factors include environmental human and mechanical and are associated with the three phases of a collision which are pre_crash at_crash and post_crash .
#
# jaccard_measure: 0.4339622641509434
# i: 131 score: 0.4339622641509434 maxScore: 0.8214285714285714
# frag-sentA: ed with the three phases of a collision which are pre_crash at_crash and post_crash .
# frag-sentB: dentified causation factors to prevent collisions of a similar nature from recurring.
#
# maxScore 0.8214285714285714
# Final 131
# jaccard_measure: 0.8214285714285714
# Sentence 131 score max: 0.8214285714285714 offsetB: 11606 lengthB: 173
#
# sent original:  4201 429198 These factors include environmental, human and mechanical and are associated with the three phases of a collision, which are pre-crash, at-crash and post-crash.
#
# sent process: 4201 429198 These factors include environmental human and mechanical and are associated with the three phases of a collision which are pre_crash at_crash and post_crash .
#
# ***************
# -----from 11779 ---- to prevPoint 11779
# -----to nextPoint 11944
# OrigSent:
#   4291 444999 The ultimate objective of the program is the utilization of these identified causation factors to prevent collisions of a similar nature from recurring.
#
# sentA: 4291 444999 The ultimate objective of the program is the utilization of these identified causation factors to prevent collisions of a similar nature from recurring .
#
# jaccard_measure: 0.88
# i: 132 score: 0.88 maxScore: 0
# frag-sentA: ified causation factors to prevent collisions of a similar nature from recurring .
# frag-sentB: tified causation factors to prevent collisions of a similar nature from recurring.
#
# -----from 11779 ---- to prevPoint 11944
# -----to nextPoint 12226
# OrigSent:
#   4291 444999 The ultimate objective of the program is the utilization of these identified causation factors to prevent collisions of a similar nature from recurring. 4449 4825100 Unit members are trained in the physics of collision analysis and reconstruction, occupant kinematics (human factor analysis), vehicle dynamics (collision damage analysis), scene photography, the use of various measuring instruments and Computer_Aided Design software.
#
# sentA: 4291 444999 The ultimate objective of the program is the utilization of these identified causation factors to prevent collisions of a similar nature from recurring .
#
# jaccard_measure: 0.3548387096774194
# i: 132 score: 0.3548387096774194 maxScore: 0.88
# frag-sentA: ified causation factors to prevent collisions of a similar nature from recurring .
# frag-sentB: aphy, the use of various measuring instruments and Computer_Aided Design software.
#
# maxScore 0.88
# Final 132
# jaccard_measure: 0.88
# Sentence 132 score max: 0.88 offsetB: 11779 lengthB: 165
#
# sent original:  4291 444999 The ultimate objective of the program is the utilization of these identified causation factors to prevent collisions of a similar nature from recurring.
#
# sent process: 4291 444999 The ultimate objective of the program is the utilization of these identified causation factors to prevent collisions of a similar nature from recurring .
#
# ***************

# %% [markdown]
# ### Testing the Alignment result

# %%
print ('oración preprocesada:', sentenceList[2][1])
print ('oración original:', text_orig[sentenceList[2][2]:sentenceList[2][3]])
# Out:
# oración preprocesada: Civilians 587 as of 2004 4 .
# oración original: Civilians
# 587 (as of 2004) [4]

# %% [markdown]
# ## Getting the Tagged Aligned Text of Whole Collection
#
# Here we have again the *file* **pairs** which contains all normalized cases, inside the normalizated collection (../norm), then we need the route to original files and finally the output directory.
#
# Rememberíng the [begining definition](#Aligned_Text_Structure) of <font color='#FA0000'>aligned text structure</font> for future phases.
#
# E.g. open the file *data/aligned/susp/suspicious-document00007.txt*
# <i>
# <p>    0	According to the legend a dish was make by servants of country kings paella were let to take mixed leftovers from the large dinner home in courtly pots .	0	154
# <p>    1	It iseafood believed that the Arabic word woulderives from the paella word which means leftovers .	154	248
# <p>    2	Take spanish dish guides Paella probably a a other rich .	248	305
# <p>    ...
# </i>
#
# $(id_K,normalized-sentence_K,original-offset_{sentence\,K},original-length_{sentence\,K})$

# %%
# %run scripts/02.2_alignNormalizedCaseList.py norm/norm_pairs norm/src/ norm/susp/ aligned/
# Out:
# The script will use as default the data folder as working directory
# suspicious-document00017.txt source-document00534.txt
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/01b_Paraph/scripts/02.2_alignNormalizedCaseList.py in <module>
#      54                                 alignedDocDict,sentenceAligner)
#      55
# ---> 56             validProcess = flow.process()
#      57             result = validProcess[0]&validProcess[1]
#      58
#
# ~/01b_Paraph/scripts/pipeline.py in process(self)
#      35                 #Normalize if you didn't before
#      36             if fileName not in self.docDict.keys():
# ---> 37                 validProcess = self.preprocess(fileName,i)
#      38             #Don't normalize again, take the value obtained before
#      39             else:
#
# ~/01b_Paraph/scripts/pipeline.py in preprocess(self, fileName, i)
#      69
#      70             #Align text with its original
# ---> 71             aligned_sents = self.stepFunc(normalized_text, original_text)
#      72
#      73             #Write the obtained structure in a text file
#
# ~/01b_Paraph/scripts/align.py in sentenceAligner(preproc_text, original_text)
#     129         #Raising error because of normalization troubles
#     130         if maxScore < 0.5:
# --> 131             raise ValueError('A normalization error detected.')
#     132
#     133         tuple = (i+1, sentA, offsetB, lengMax)
#
# ValueError: A normalization error detected.

# %% [markdown]
# # Conclusions
#
# The objective of this process was accomplished. The obtained transformed text contains the proposed structure. 1361 pairs of text (cases) were obtaibned previously from the 2000 initial normalized list using initial versions. Then we re-aligned thems to show the process of alignment using 02.2_alignNormalizedCaseList.py script. In the final version of this script we get 2000 pair cases thanks to fine dev of func _normalize()_.
#
# Although 2.2 script use the Jaccard alignment algorithm and the 100% of the cases were good aligned after normalization, it is very easy to test other similarity distances or alignment knowleage in a different corpus and obtain different results and performance, based on original_text_corpus particularities.

# %% [markdown]
# # Excersices
#
# 1. The comparison between alignment text using Smith-Waterman and the algh presented here can show a different performance. Implement a new alignment pipeline using another faster technique and less source code.
#
# 2. Make a list of different punctuation situations that can appear in real text provided by pdftotext conversors and program the regular expresion for both sides the normalization process and for normalize function. Construct a test unit with your ideas and finally test them in the same way we did here.
#
# 3. Create a different idea to align original and preprocessed sentences. Sugestion, take a look to cross-lingual alignment implemented in nltk.
#
# 4. In the script/align.py version of this alignment algorithm The next code was added to the alignment pipeline to improve the alignment of long sentences. Evaluate it and propose the best k to maintain the precision.
#
#         #Optimization for very long sentences alignment
#         if len(sentA) > 500:
#             k = 0.1
#         else: k=0.5
#
# 5. The pairs list provided for this tutorial(_norm_pairs_) contains 2000 cases in which the Jaccard based aligment makes a perfect score. If this algorithm is tested on all PAN-PC pairs file the result could be very different, some cases will be bad aligned. Make the necessary changes to the algorithm to write in the alignedDocDict file a "False" value if the text is bad aligned. (_Sugestion: study the script/align.py file_)
